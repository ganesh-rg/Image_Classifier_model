# %% [markdown]
# # Image Classification

# %%
import tensorflow as tf

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import cv2
import os
import imghdr
import matplotlib.pyplot as plt

# %%
data_dir = "C://Users//Dell//Darasets"

# %%
image_extentions = ["jpeg","jpg","png","bmp"]

# %%
for images in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, images)):
        image_path = os.path.join(data_dir,images,image)
        try:
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_extentions:
                os.remove(image_path)
        except Exception as e:
            print("Issue with image {}".format(image_path))

# %%
img = cv2.imread(r"C:\Users\Dell\Darasets\cars\806tr3a_1586569.jpg")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (415, 664, 3)

# %% [markdown]
# ## Loading Images

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf

# %%
data = tf.keras.utils.image_dataset_from_directory("C://Users//Dell//Darasets",image_size=(224,224),batch_size=5)
# Out:
# Found 1132 files belonging to 3 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
batch[1]
# Out:
# array([0, 0, 0, 2, 2])

# %%
fig, ax = plt.subplots(ncols = 4, figsize= (20,20))
for idx, img in enumerate(batch[0][:4]):
  ax[idx].imshow(img.astype(int))
  ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# ## Data prepocessing

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
data.as_numpy_iterator().next()[0].max()
# Out:
# 1.0

# %% [markdown]
# ### Spliting Data

# %%
train_size = int(len(data)*.7)
test_size = int(len(data)*.1)+2
val_size = int(len(data)*.2)

# %%
train_size+val_size+test_size == len(data)
# Out:
# True

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# ## Building Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, Softmax
import tensorflow as tf

# %%
model = Sequential()

# %%
model.add(Conv2D(64, (3,3), 1,padding = "same", activation = "relu", input_shape = (224,224,3)))
model.add(Conv2D(64, (3,3), 1, padding = "same", activation = "relu"))
model.add(MaxPooling2D(strides = 2))

model.add(Conv2D(128, (3,3), 1, padding = "same", activation = "relu"))
model.add(MaxPooling2D(strides = 2))

model.add(Conv2D(256, (3,3), 1, padding = "same", activation = "relu"))
model.add(MaxPooling2D(strides = 2))

model.add(Conv2D(512, (3,3), 1, padding = "same", activation = "relu"))
model.add(MaxPooling2D(strides = 2))

model.add(Flatten())
model.add(Dense(500,activation = "relu"))
model.add(Dropout(0.5))

model.add(Dense(500,activation = "relu"))
model.add(Dropout(0.5))

model.add(Dense(3,activation = "softmax"))
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[52], line 11
#       9 model.add(MaxPooling2D(strides = 2))
#      10 model.add(Flatten())
# ---> 11 model.add(Dense(200,activation = "relu"))
#      12 model.add(Dropout(0.3))
#      13 model.add(Dense(200,activation = "relu"))
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
# ...

# %%
model.compile("adam",loss=tf.keras.losses.SparseCategoricalCrossentropy(), metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 224, 224, 64)      1792
#
#  conv2d_7 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d_3 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_9 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_4 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_11 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_5 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
# ...

# %%
logdir = "logs"

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logdir)

# %%
hist = model.fit(train, epochs = 20, validation_data = val, callbacks = [tensorboard_callback])
# Out:
# Epoch 1/10
# 158/158 [==============================] - 53s 331ms/step - loss: 1.0486 - accuracy: 0.4304 - val_loss: 1.0247 - val_accuracy: 0.5244
# Epoch 2/10
# 158/158 [==============================] - 57s 359ms/step - loss: 1.0504 - accuracy: 0.4354 - val_loss: 1.0440 - val_accuracy: 0.4978
# Epoch 3/10
# 158/158 [==============================] - 57s 362ms/step - loss: 1.0500 - accuracy: 0.4329 - val_loss: 1.0353 - val_accuracy: 0.5067
# Epoch 4/10
# 158/158 [==============================] - 58s 368ms/step - loss: 1.0475 - accuracy: 0.4329 - val_loss: 1.0433 - val_accuracy: 0.5022
# Epoch 5/10
# 158/158 [==============================] - 60s 377ms/step - loss: 1.0457 - accuracy: 0.4392 - val_loss: 1.0366 - val_accuracy: 0.5022
# Epoch 6/10
# 158/158 [==============================] - 71s 451ms/step - loss: 1.0498 - accuracy: 0.4342 - val_loss: 1.0522 - val_accuracy: 0.4933
# Epoch 7/10
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 gpu_options = tf.GpuOptions(allow_growth=True)
#       2 session = tf.InteractiveSession(config=tf.ConfigProto(gpu_options=gpu_options))
#
# AttributeError: module 'tensorflow' has no attribute 'GpuOptions'
